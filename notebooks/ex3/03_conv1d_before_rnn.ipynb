# %% [markdown]
# # Doel van dit notebook
# In dit experiment onderzoek ik of een Conv1D-laag vóór een GRU helpt bij gesture-classificatie.
# Hypothese: lokale temporele patronen (acceleratie-pieken) kunnen door Conv1D beter worden geëxtraheerd voordat de RNN de sequentie samenvat.
# Ik vergelijk dit model met de eerdere GRU + mean-pooling baseline, met identieke data- en trainingsinstellingen.

# %%
import sys
from pathlib import Path

# Vind repo-root door omhoog te lopen totdat we pyproject.toml of .git vinden
p = Path().resolve()
while not (p / "pyproject.toml").exists() and not (p / ".git").exists():
    if p.parent == p:
        raise RuntimeError("Repo root not found (no pyproject.toml/.git).")
    p = p.parent

PROJECT_ROOT = p
sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added to sys.path:", PROJECT_ROOT)
# Out:
# Project root added to sys.path: /home/mischatrader1/MADS/MADS-MachineLearning-course

# %%
from pathlib import Path

import torch

from mads_datasets import DatasetFactoryProvider, DatasetType
from mltrainer.preprocessors import PaddedPreprocessor

from mltrainer import TrainerSettings, ReportTypes
from mltrainer.metrics import Accuracy

# %%
import torch

if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
    print("Using MPS")
elif torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Using CUDA")
else:
    device = torch.device("cpu")
    print("Using CPU")

# Override naar CPU voor kleine RNN-modellen indien gewenst
device = torch.device("cpu")

device
# Out:
# Using CPU
# /home/mischatrader1/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# device(type='cpu')

# %%
# Data + preprocessor (identiek aan notebook 02)
preprocessor = PaddedPreprocessor()

gestures_factory = DatasetFactoryProvider.create_factory(DatasetType.GESTURES)
streamers = gestures_factory.create_datastreamer(batchsize=32, preprocessor=preprocessor)

train = streamers["train"]
valid = streamers["valid"]

trainstreamer = train.stream()
validstreamer = valid.stream()

len(train), len(valid)
# Out:
# 2026-01-08 17:22:03.216 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/mischatrader1/.cache/mads_datasets/gestures
# 100%|██████████| 2600/2600 [00:02<00:00, 1254.08it/s]
# 100%|██████████| 651/651 [00:00<00:00, 1145.02it/s]
# (81, 20)

# %%
accuracy = Accuracy()

settings = TrainerSettings(
    epochs=30,  # bewust korter dan "100": dit notebook is een gerichte vergelijking
    metrics=[accuracy],
    logdir=Path("gestures_ex3"),
    train_steps=len(train),
    valid_steps=len(valid),
    reporttypes=[ReportTypes.TOML, ReportTypes.TENSORBOARD, ReportTypes.MLFLOW],
    scheduler_kwargs={"factor": 0.5, "patience": 5},
    earlystop_kwargs={
        "save": False,
        "verbose": True,
        "patience": 5,
        "delta": 0.0,
    },
)
settings
# Out:
# epochs: 30
# metrics: [Accuracy]
# logdir: gestures_ex3
# train_steps: 81
# valid_steps: 20
# reporttypes: [<ReportTypes.TOML: 'TOML'>, <ReportTypes.TENSORBOARD: 'TENSORBOARD'>, <ReportTypes.MLFLOW: 'MLFLOW'>]
# optimizer_kwargs: {'lr': 0.001, 'weight_decay': 1e-05}
# scheduler_kwargs: {'factor': 0.5, 'patience': 5}
# earlystop_kwargs: {'save': False, 'verbose': True, 'patience': 5, 'delta': 0.0}

# %%
from src_rnn.models import RNNConfig
from src_rnn.run_experiment import run_experiment

# %%
# # Run: Conv1D vóór GRU (experiment)
config = RNNConfig(
    input_size=3,
    hidden_size=64,
    num_layers=1,
    output_size=20,
    dropout=0.0,
)

_ = run_experiment(
    model_name="conv1d_gru_mean",                 # baseline: last-step representatie
    config=config,
    settings=settings,
    trainstreamer=train.stream(),
    validstreamer=valid.stream(),
    device=device,
    experiment_name="gestures-ex3",
    run_name="03_conv1d_gru_mean_h64_l1",
)
# Out:
# 2026/01/08 17:22:06 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 0.1 seconds
# 2026/01/08 17:22:06 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 0.3 seconds
# 2026/01/08 17:22:07 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 0.7 seconds
# 2026/01/08 17:22:07 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 1.5 seconds
# 2026/01/08 17:22:09 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 3.1 seconds
# 2026/01/08 17:22:12 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 6.3 seconds
# 2026/01/08 17:22:18 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 12.7 seconds
# 2026/01/08 17:22:31 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 25.5 seconds
# 2026/01/08 17:22:57 WARNING mlflow.store.db.utils: SQLAlchemy engine could not be created. The following exception is caught.
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Operation will be retried in 51.1 seconds
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)    447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 10
#       1 # # Run: Conv1D vóór GRU (experiment)
#       2 config = RNNConfig(
#       3     input_size=3,
#       4     hidden_size=64,
#    (...)      7     dropout=0.0,
#       8 )
# ---> 10 _ = run_experiment(
#      11     model_name="conv1d_gru_mean",                 # baseline: last-step representatie
#      12     config=config,
#      13     settings=settings,
#      14     trainstreamer=train.stream(),
#      15     validstreamer=valid.stream(),
#      16     device=device,
#      17     experiment_name="gestures-ex3",
#      18     run_name="03_conv1d_gru_mean_h64_l1",
#      19 )
#
# File ~/MADS/MADS-MachineLearning-course/src_rnn/run_experiment.py:38, in run_experiment(model_name, config, settings, trainstreamer, validstreamer, device, experiment_name, run_name, tracking_uri, lr, weight_decay, extra_tags)
#      36 # MLflow setup
#      37 mlflow.set_tracking_uri(tracking_uri)
# ---> 38 mlflow.set_experiment(experiment_name)
#      40 # Build model
#      41 model = build_model(model_name=model_name, config=config).to(device)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/fluent.py:153, in set_experiment(experiment_name, experiment_id)
#     145 if (experiment_name is not None and experiment_id is not None) or (
#     146     experiment_name is None and experiment_id is None
#     147 ):
#     148     raise MlflowException(
#     149         message="Must specify exactly one of: `experiment_id` or `experiment_name`.",
#     150         error_code=INVALID_PARAMETER_VALUE,
#     151     )
# --> 153 client = MlflowClient()
#     155 with _experiment_lock:
#     156     if experiment_id is None:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/client.py:159, in MlflowClient.__init__(self, tracking_uri, registry_uri)
#     157 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     158 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 159 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:84, in TrackingServiceClient.__init__(self, tracking_uri)
#      79 self.tracking_uri = tracking_uri
#      80 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      81 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      82 # property method to ensure that the client is serializable, even if the store is not
#      83 # self.store
# ---> 84 self.store
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:88, in TrackingServiceClient.store(self)
#      86 @property
#      87 def store(self):
# ---> 88     return utils._get_store(self.tracking_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:210, in _get_store(store_uri, artifact_uri)
#     209 def _get_store(store_uri=None, artifact_uri=None):
# --> 210     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:142, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     140 if artifact_uri is None:
#     141     artifact_uri = DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
# --> 142 return SqlAlchemyStore(store_uri, artifact_uri)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:169, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root)
#     161     with SqlAlchemyStore._db_uri_sql_alchemy_engine_map_lock:
#     162         # Repeat check to prevent race conditions where one thread checks for an existing
#     163         # engine while another is creating the respective one, resulting in multiple
#     164         # engines being created. It isn't combined with the above check to prevent
#     165         # inefficiency from multiple threads waiting for the lock to check for engine
#     166         # existence if it has already been created.
#     167         if db_uri not in SqlAlchemyStore._db_uri_sql_alchemy_engine_map:
#     168             SqlAlchemyStore._db_uri_sql_alchemy_engine_map[db_uri] = (
# --> 169                 mlflow.store.db.utils.create_sqlalchemy_engine_with_retry(db_uri)
#     170             )
#     171 self.engine = SqlAlchemyStore._db_uri_sql_alchemy_engine_map[db_uri]
#     172 # On a completely fresh MLflow installation against an empty database (verify database
#     173 # emptiness by checking that 'experiments' etc aren't in the list of table names), run all
#     174 # DB migrations
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/mlflow/store/db/utils.py:245, in create_sqlalchemy_engine_with_retry(db_uri)
#     243 engine = create_sqlalchemy_engine(db_uri)
#     244 try:
# --> 245     sqlalchemy.inspect(engine)
#     246     return engine
#     247 except Exception as e:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/inspection.py:140, in inspect(subject, raiseerr)
#     138 elif reg is True:
#     139     return subject
# --> 140 ret = reg(subject)
#     141 if ret is not None:
#     142     return ret
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:313, in Inspector._engine_insp(bind)
#     311 @inspection._inspects(Engine)
#     312 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 313     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:246, in Inspector._construct(cls, init, bind)
#     243     cls = bind.dialect.inspector
#     245 self = cls.__new__(cls)
# --> 246 init(self, bind)
#     247 return self
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:257, in Inspector._init_engine(self, engine)
#     255 def _init_engine(self, engine: Engine) -> None:
#     256     self.bind = self.engine = engine
# --> 257     engine.connect().close()
#     258     self._op_context_requires_connect = True
#     259     self.dialect = self.engine.dialect
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3273, in Engine.connect(self)
#    3250 def connect(self) -> Connection:
#    3251     """Return a new :class:`_engine.Connection` object.
#    3252
#    3253     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3270
#    3271     """
# -> 3273     return self._connection_cls(self)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2436, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2434 elif should_wrap:
#    2435     assert sqlalchemy_exception is not None
# -> 2436     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2437 else:
#    2438     assert exc_info[1] is not None
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3297, in Engine.raw_connection(self)
#    3275 def raw_connection(self) -> PoolProxiedConnection:
#    3276     """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278     The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296     """
# -> 3297     return self.pool.connect()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)    447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/MADS/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
