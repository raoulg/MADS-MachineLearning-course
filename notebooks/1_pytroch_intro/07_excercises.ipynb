# %%
import torch
import seaborn as sns
import sys
from pathlib import Path
sys.path.insert(0, "../..")

# %%
from src.data import make_dataset
from src.models import imagemodels
from src.models import train_model
import gin

# %%
gin.parse_config_file("model.gin")
# Out:
# ParsedConfigFileIncludesAndImports(filename='model.gin', imports=['gin.torch.external_configurables'], includes=[])

# %% [markdown]
# We will be using `gin-config` to easily keep track of our experiments, and to easily save the different things we did during our experiments.
#
# The `model.gin` file is a simple file that will try to load parameters for funcitons that are already imported.
#
# So, if you wouldnt have imported train_model, the ginfile would not be able to parse settings for train_model.trainloop and will give an error.
#
# We can print all the settings that are operational with `gin.operative_config_str()` once we have loaded the functions to memory.

# %% [markdown]
# So, while `.get_MNIST()` has two parameters that need to be set (a batchsize and a datadir), we can now load the function without having to do that: gin has done it already for us.

# %%
train_dataloader, test_dataloader = make_dataset.get_MNIST()

# %%
print(gin.config_str())
# Out:
# import gin.torch.external_configurables
#
# # Parameters for get_MNIST:
# # ==============================================================================
# get_MNIST.batch_size = 32
# get_MNIST.data_dir = '../../data/raw'
#
# # Parameters for NeuralNetwork:
# # ==============================================================================
# NeuralNetwork.num_classes = 10
# NeuralNetwork.units1 = 512
#
# # Parameters for trainloop:
# # ==============================================================================
# trainloop.epochs = 10
# trainloop.learning_rate = 0.001
# trainloop.log_dir = '../../models/gtest/'
# trainloop.loss_fn = @CrossEntropyLoss()
# trainloop.optimizer = @Adam

# %% [markdown]
# A big advantage is that we can save this config as a file; that way it is easy to track what you changed during your experiments.

# %%
from src.models import metrics
accuracy = metrics.Accuracy()

# %%
import torch.optim as optim
gin.parse_config_file("model.gin")

units = [512, 256, 128]
learning_rate = [0.01, 0.001, 0.0001]

for unit in units:
    for lr in learning_rate:
        gin.bind_parameter("NeuralNetwork.units2", unit)
        gin.bind_parameter("trainloop.learning_rate", lr)
    
        model = imagemodels.NeuralNetwork()

        model =  train_model.trainloop(
            epochs=10,
            model=model,
            metrics=[accuracy],
            train_dataloader=train_dataloader,
            test_dataloader=test_dataloader,
            train_steps=len(train_dataloader),
            eval_steps=150,
        )
# Out:
# 2022-11-28 23:24:46.139 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2324
# 100%|██████████| 1875/1875 [00:08<00:00, 230.04it/s]
# 2022-11-28 23:24:54.637 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.5737 test 0.4973 metric ['0.8321']
# 100%|██████████| 1875/1875 [00:07<00:00, 235.66it/s]
# 2022-11-28 23:25:02.866 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4687 test 0.4549 metric ['0.8392']
# 100%|██████████| 1875/1875 [00:08<00:00, 222.80it/s]
# 2022-11-28 23:25:11.637 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.4284 test 0.4726 metric ['0.8396']
# 100%|██████████| 1875/1875 [00:07<00:00, 234.76it/s]
# 2022-11-28 23:25:19.869 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.4238 test 0.4933 metric ['0.8204']
# 100%|██████████| 1875/1875 [00:07<00:00, 237.21it/s]
# 2022-11-28 23:25:28.023 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.4063 test 0.4433 metric ['0.8442']
# 100%|██████████| 1875/1875 [00:07<00:00, 238.98it/s]
# 2022-11-28 23:25:36.119 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.4135 test 0.4685 metric ['0.8352']
# 100%|██████████| 1875/1875 [00:07<00:00, 243.99it/s]
# 2022-11-28 23:25:44.042 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.4032 test 0.5033 metric ['0.8406']
# 100%|██████████| 1875/1875 [00:07<00:00, 243.98it/s]
# 2022-11-28 23:25:51.974 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.3984 test 0.4548 metric ['0.8373']
# 100%|██████████| 1875/1875 [00:07<00:00, 243.82it/s]
# 2022-11-28 23:25:59.904 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.3947 test 0.4510 metric ['0.8402']
# 100%|██████████| 1875/1875 [00:07<00:00, 237.86it/s]
# 2022-11-28 23:26:08.058 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.3956 test 0.5247 metric ['0.8181']
# 100%|██████████| 10/10 [01:21<00:00,  8.18s/it]
# 2022-11-28 23:26:08.062 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2326
# 100%|██████████| 1875/1875 [00:07<00:00, 238.51it/s]
# 2022-11-28 23:26:16.203 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.4689 test 0.4173 metric ['0.8469']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.04it/s]
# 2022-11-28 23:26:24.066 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.3423 test 0.3769 metric ['0.8644']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.98it/s]
# 2022-11-28 23:26:31.899 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3132 test 0.3660 metric ['0.8669']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.33it/s]
# 2022-11-28 23:26:39.747 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.2913 test 0.3289 metric ['0.8754']
# 100%|██████████| 1875/1875 [00:07<00:00, 247.45it/s]
# 2022-11-28 23:26:47.566 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.2755 test 0.4308 metric ['0.8448']
# 100%|██████████| 1875/1875 [00:07<00:00, 247.62it/s]
# 2022-11-28 23:26:55.377 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.2561 test 0.3457 metric ['0.8794']
# 100%|██████████| 1875/1875 [00:07<00:00, 248.69it/s]
# 2022-11-28 23:27:03.155 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.2427 test 0.3358 metric ['0.8821']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.89it/s]
# 2022-11-28 23:27:10.991 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.2304 test 0.3439 metric ['0.8869']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.10it/s]
# 2022-11-28 23:27:18.848 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2244 test 0.3477 metric ['0.8842']
# 100%|██████████| 1875/1875 [00:07<00:00, 246.14it/s]
# 2022-11-28 23:27:26.708 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2164 test 0.3311 metric ['0.8883']
# 100%|██████████| 10/10 [01:18<00:00,  7.86s/it]
# 2022-11-28 23:27:26.712 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2327
# 100%|██████████| 1875/1875 [00:07<00:00, 236.88it/s]
# 2022-11-28 23:27:34.900 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.5978 test 0.4773 metric ['0.8298']
# 100%|██████████| 1875/1875 [00:07<00:00, 235.67it/s]
# 2022-11-28 23:27:43.102 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4085 test 0.4143 metric ['0.8423']
# 100%|██████████| 1875/1875 [00:07<00:00, 237.91it/s]
# 2022-11-28 23:27:51.228 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3635 test 0.3930 metric ['0.8617']
# 100%|██████████| 1875/1875 [00:07<00:00, 241.81it/s]
# 2022-11-28 23:27:59.221 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.3366 test 0.3858 metric ['0.8617']
# 100%|██████████| 1875/1875 [00:07<00:00, 240.86it/s]
# 2022-11-28 23:28:07.241 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.3176 test 0.3645 metric ['0.8679']
# 100%|██████████| 1875/1875 [00:07<00:00, 242.66it/s]
# 2022-11-28 23:28:15.213 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.3008 test 0.3296 metric ['0.8798']
# 100%|██████████| 1875/1875 [00:07<00:00, 241.00it/s]
# 2022-11-28 23:28:23.244 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.2806 test 0.3406 metric ['0.8740']
# 100%|██████████| 1875/1875 [00:07<00:00, 238.24it/s]
# 2022-11-28 23:28:31.359 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.2667 test 0.3403 metric ['0.8794']
# 100%|██████████| 1875/1875 [00:07<00:00, 236.17it/s]
# 2022-11-28 23:28:39.537 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2548 test 0.3144 metric ['0.8881']
# 100%|██████████| 1875/1875 [00:07<00:00, 240.73it/s]
# 2022-11-28 23:28:47.574 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2480 test 0.3108 metric ['0.8865']
# 100%|██████████| 10/10 [01:20<00:00,  8.08s/it]
# 2022-11-28 23:28:47.577 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2328
# 100%|██████████| 1875/1875 [00:07<00:00, 259.51it/s]
# 2022-11-28 23:28:55.073 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.5477 test 0.4836 metric ['0.8385']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.75it/s]
# 2022-11-28 23:29:02.337 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4467 test 0.5490 metric ['0.8233']
# 100%|██████████| 1875/1875 [00:06<00:00, 269.59it/s]
# 2022-11-28 23:29:09.529 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.4183 test 0.4643 metric ['0.8383']
# 100%|██████████| 1875/1875 [00:06<00:00, 269.19it/s]
# 2022-11-28 23:29:16.726 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.4069 test 0.4638 metric ['0.8333']
# 100%|██████████| 1875/1875 [00:07<00:00, 260.22it/s]
# 2022-11-28 23:29:24.169 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.4034 test 0.4262 metric ['0.8533']
# 100%|██████████| 1875/1875 [00:07<00:00, 260.54it/s]
# 2022-11-28 23:29:31.617 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.3949 test 0.4634 metric ['0.8373']
# 100%|██████████| 1875/1875 [00:07<00:00, 248.84it/s]
# 2022-11-28 23:29:39.392 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.3847 test 0.4710 metric ['0.8444']
# 100%|██████████| 1875/1875 [00:07<00:00, 258.46it/s]
# 2022-11-28 23:29:46.893 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.3808 test 0.4376 metric ['0.8596']
# 100%|██████████| 1875/1875 [00:07<00:00, 258.47it/s]
# 2022-11-28 23:29:54.386 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.3740 test 0.4198 metric ['0.8446']
# 100%|██████████| 1875/1875 [00:07<00:00, 261.44it/s]
# 2022-11-28 23:30:01.796 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.3764 test 0.4959 metric ['0.8469']
# 100%|██████████| 10/10 [01:14<00:00,  7.42s/it]
# 2022-11-28 23:30:01.800 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2330
# 100%|██████████| 1875/1875 [00:07<00:00, 253.45it/s]
# 2022-11-28 23:30:09.473 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.4739 test 0.3967 metric ['0.8512']
# 100%|██████████| 1875/1875 [00:07<00:00, 252.66it/s]
# 2022-11-28 23:30:17.145 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.3502 test 0.4530 metric ['0.8335']
# 100%|██████████| 1875/1875 [00:07<00:00, 255.18it/s]
# 2022-11-28 23:30:24.738 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3155 test 0.3727 metric ['0.8683']
# 100%|██████████| 1875/1875 [00:07<00:00, 254.90it/s]
# 2022-11-28 23:30:32.342 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.2938 test 0.3752 metric ['0.8667']
# 100%|██████████| 1875/1875 [00:07<00:00, 250.13it/s]
# 2022-11-28 23:30:40.081 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.2713 test 0.3324 metric ['0.8879']
# 100%|██████████| 1875/1875 [00:07<00:00, 256.83it/s]
# 2022-11-28 23:30:47.624 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.2574 test 0.3275 metric ['0.8850']
# 100%|██████████| 1875/1875 [00:07<00:00, 254.83it/s]
# 2022-11-28 23:30:55.225 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.2476 test 0.3349 metric ['0.8858']
# 100%|██████████| 1875/1875 [00:07<00:00, 254.54it/s]
# 2022-11-28 23:31:02.841 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.2348 test 0.3737 metric ['0.8812']
# 100%|██████████| 1875/1875 [00:07<00:00, 256.29it/s]
# 2022-11-28 23:31:10.393 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2242 test 0.3598 metric ['0.8767']
# 100%|██████████| 1875/1875 [00:07<00:00, 255.03it/s]
# 2022-11-28 23:31:17.985 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2128 test 0.3789 metric ['0.8790']
# 100%|██████████| 10/10 [01:16<00:00,  7.62s/it]
# 2022-11-28 23:31:17.988 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2331
# 100%|██████████| 1875/1875 [00:07<00:00, 256.18it/s]
# 2022-11-28 23:31:25.581 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.6225 test 0.4687 metric ['0.8315']
# 100%|██████████| 1875/1875 [00:07<00:00, 252.03it/s]
# 2022-11-28 23:31:33.258 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4145 test 0.4347 metric ['0.8475']
# 100%|██████████| 1875/1875 [00:07<00:00, 252.40it/s]
# 2022-11-28 23:31:40.924 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3792 test 0.3881 metric ['0.8608']
# 100%|██████████| 1875/1875 [00:07<00:00, 250.51it/s]
# 2022-11-28 23:31:48.650 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.3499 test 0.4043 metric ['0.8588']
# 100%|██████████| 1875/1875 [00:07<00:00, 249.73it/s]
# 2022-11-28 23:31:56.403 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.3284 test 0.3810 metric ['0.8638']
# 100%|██████████| 1875/1875 [00:07<00:00, 251.45it/s]
# 2022-11-28 23:32:04.105 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.3134 test 0.3504 metric ['0.8733']
# 100%|██████████| 1875/1875 [00:07<00:00, 261.24it/s]
# 2022-11-28 23:32:11.528 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.2957 test 0.3450 metric ['0.8775']
# 100%|██████████| 1875/1875 [00:07<00:00, 254.34it/s]
# 2022-11-28 23:32:19.138 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.2890 test 0.3450 metric ['0.8777']
# 100%|██████████| 1875/1875 [00:07<00:00, 248.35it/s]
# 2022-11-28 23:32:26.932 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2751 test 0.3160 metric ['0.8879']
# 100%|██████████| 1875/1875 [00:07<00:00, 245.49it/s]
# 2022-11-28 23:32:34.820 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2608 test 0.3638 metric ['0.8706']
# 100%|██████████| 10/10 [01:16<00:00,  7.68s/it]
# 2022-11-28 23:32:34.825 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2332
# 100%|██████████| 1875/1875 [00:07<00:00, 263.68it/s]
# 2022-11-28 23:32:42.199 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.5452 test 0.5879 metric ['0.7992']
# 100%|██████████| 1875/1875 [00:07<00:00, 265.03it/s]
# 2022-11-28 23:32:49.511 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4395 test 0.4178 metric ['0.8512']
# 100%|██████████| 1875/1875 [00:07<00:00, 262.95it/s]
# 2022-11-28 23:32:56.885 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.4067 test 0.4776 metric ['0.8331']
# 100%|██████████| 1875/1875 [00:07<00:00, 265.59it/s]
# 2022-11-28 23:33:04.175 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.4064 test 0.4635 metric ['0.8462']
# 100%|██████████| 1875/1875 [00:07<00:00, 260.22it/s]
# 2022-11-28 23:33:11.615 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.3888 test 0.4488 metric ['0.8485']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.96it/s]
# 2022-11-28 23:33:18.871 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.3985 test 0.4785 metric ['0.8438']
# 100%|██████████| 1875/1875 [00:07<00:00, 267.42it/s]
# 2022-11-28 23:33:26.118 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.3846 test 0.4471 metric ['0.8406']
# 100%|██████████| 1875/1875 [00:07<00:00, 265.68it/s]
# 2022-11-28 23:33:33.414 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.3844 test 0.4431 metric ['0.8365']
# 100%|██████████| 1875/1875 [00:07<00:00, 264.02it/s]
# 2022-11-28 23:33:40.746 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.3768 test 0.4247 metric ['0.8565']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.13it/s]
# 2022-11-28 23:33:47.965 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.3784 test 0.4656 metric ['0.8452']
# 100%|██████████| 10/10 [01:13<00:00,  7.31s/it]
# 2022-11-28 23:33:47.969 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2333
# 100%|██████████| 1875/1875 [00:07<00:00, 261.14it/s]
# 2022-11-28 23:33:55.421 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.4729 test 0.4683 metric ['0.8375']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.41it/s]
# 2022-11-28 23:34:02.690 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.3508 test 0.4085 metric ['0.8450']
# 100%|██████████| 1875/1875 [00:07<00:00, 267.26it/s]
# 2022-11-28 23:34:09.939 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3211 test 0.3999 metric ['0.8650']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.32it/s]
# 2022-11-28 23:34:17.225 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.2915 test 0.3905 metric ['0.8623']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.41it/s]
# 2022-11-28 23:34:24.446 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.2701 test 0.3552 metric ['0.8704']
# 100%|██████████| 1875/1875 [00:06<00:00, 271.48it/s]
# 2022-11-28 23:34:31.586 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.2610 test 0.3334 metric ['0.8835']
# 100%|██████████| 1875/1875 [00:07<00:00, 264.05it/s]
# 2022-11-28 23:34:38.922 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.2424 test 0.3198 metric ['0.8827']
# 100%|██████████| 1875/1875 [00:06<00:00, 267.99it/s]
# 2022-11-28 23:34:46.159 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.2349 test 0.3690 metric ['0.8700']
# 100%|██████████| 1875/1875 [00:06<00:00, 267.97it/s]
# 2022-11-28 23:34:53.391 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2218 test 0.3604 metric ['0.8806']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.97it/s]
# 2022-11-28 23:35:00.591 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2126 test 0.3250 metric ['0.8875']
# 100%|██████████| 10/10 [01:12<00:00,  7.26s/it]
# 2022-11-28 23:35:00.594 | INFO     | src.data.data_tools:dir_add_timestamp:114 - Logging to ../../models/gtest/20221128-2335
# 100%|██████████| 1875/1875 [00:06<00:00, 269.40it/s]
# 2022-11-28 23:35:07.819 | INFO     | src.models.train_model:trainloop:171 - Epoch 0 train 0.6591 test 0.4946 metric ['0.8279']
# 100%|██████████| 1875/1875 [00:07<00:00, 262.77it/s]
# 2022-11-28 23:35:15.184 | INFO     | src.models.train_model:trainloop:171 - Epoch 1 train 0.4366 test 0.4436 metric ['0.8406']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.99it/s]
# 2022-11-28 23:35:22.385 | INFO     | src.models.train_model:trainloop:171 - Epoch 2 train 0.3876 test 0.4206 metric ['0.8554']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.81it/s]
# 2022-11-28 23:35:29.585 | INFO     | src.models.train_model:trainloop:171 - Epoch 3 train 0.3656 test 0.4042 metric ['0.8527']
# 100%|██████████| 1875/1875 [00:07<00:00, 267.42it/s]
# 2022-11-28 23:35:36.825 | INFO     | src.models.train_model:trainloop:171 - Epoch 4 train 0.3402 test 0.3584 metric ['0.8667']
# 100%|██████████| 1875/1875 [00:06<00:00, 269.65it/s]
# 2022-11-28 23:35:44.011 | INFO     | src.models.train_model:trainloop:171 - Epoch 5 train 0.3301 test 0.3572 metric ['0.8706']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.57it/s]
# 2022-11-28 23:35:51.274 | INFO     | src.models.train_model:trainloop:171 - Epoch 6 train 0.3120 test 0.3360 metric ['0.8779']
# 100%|██████████| 1875/1875 [00:07<00:00, 266.46it/s]
# 2022-11-28 23:35:58.538 | INFO     | src.models.train_model:trainloop:171 - Epoch 7 train 0.3002 test 0.3662 metric ['0.8690']
# 100%|██████████| 1875/1875 [00:06<00:00, 268.84it/s]
# 2022-11-28 23:36:05.748 | INFO     | src.models.train_model:trainloop:171 - Epoch 8 train 0.2891 test 0.3537 metric ['0.8706']
# 100%|██████████| 1875/1875 [00:06<00:00, 271.91it/s]
# 2022-11-28 23:36:12.877 | INFO     | src.models.train_model:trainloop:171 - Epoch 9 train 0.2760 test 0.3405 metric ['0.8767']
# 100%|██████████| 10/10 [01:12<00:00,  7.22s/it]

# %% [markdown]
# Run the experiment, and study the result with tensorboard.
#
# Locally, it is easy to do that with VS code itself. On the server, you have to take these steps:
#
# - in the terminal, navigate to ~/code/ML22
# - activate the python environment for the shell with `poetry shell`. Note how the correct environment is being activated.
# - run `tensorboard --logdir=models` in the terminal
# - tensorboard will launch at `localhost:6006` and vscode will notify you that the port is forwarded
# - you can either press the `launch` button in VScode or open your local browser at `localhost:6006`

# %% [markdown]
# Experiment with things like:
#
# - changing the amount of units1 and units2 to values between 16 and 1024. Use factors of 2: 16, 32, 64, etc.
# - changing the batchsize to values between 4 and 128. Again, use factors of two.
# - all your experiments are saved in the `models` directory, with a timestamp. Inside you find a saved_config.gin file, that
# contains all the settings for that experiment. The `events` file is what tensorboard will show.
# - plot the result in a heatmap: units vs batchsize.
# - changing the learningrate to values between 1e-2 and 1e-5
# - changing the optimizer from SGD to one of the other available algoritms at [torch](https://pytorch.org/docs/stable/optim.html) (scroll down for the algorithms)
#
# A note on train_steps: this is a setting that determines how often you get an update.
# Because our complete dataset is 938 (60000 / 64) batches long, you will need 938 trainstep to cover the complete 60.000 images.
#
# This can actually be a bit confusion, because every value below 938 changes the meaning of `epoch` slightly, because one epoch is no longer
# the full dataset, but simply `trainstep` batches. Setting trainsteps to 100 means you need to wait twice as long before you get feedback on the performance,
# as compared to trainsteps=50. You will also see that settings trainsteps to 100 improves the learning, but that is simply because the model has seen twice as
# much examples as compared to trainsteps=50.
#
# This implies that it is not usefull to compare trainsteps=50 and trainsteps=100, because setting it to 100 will always be better.
# Just pick an amount, and adjust your number of epochs accordingly.
